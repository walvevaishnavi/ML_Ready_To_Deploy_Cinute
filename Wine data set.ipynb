# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).

# %%
#/content/drive/MyDrive/Machine learning/wine_quality_merged.csv

# %%
import pandas as pd

# %%
data=pd.read_csv("/content/drive/MyDrive/Machine learning/wine_quality_merged.csv")

# %%
data.head(10)
# Out:
#    fixed acidity  volatile acidity  citric acid  residual sugar  chlorides  \
# 0            7.4              0.70         0.00             1.9      0.076
# 1            7.8              0.88         0.00             2.6      0.098
# 2            7.8              0.76         0.04             2.3      0.092
# 3           11.2              0.28         0.56             1.9      0.075
# 4            7.4              0.70         0.00             1.9      0.076
# 5            7.4              0.66         0.00             1.8      0.075
# 6            7.9              0.60         0.06             1.6      0.069
# 7            7.3              0.65         0.00             1.2      0.065
# 8            7.8              0.58         0.02             2.0      0.073
# 9            7.5              0.50         0.36             6.1      0.071
#
#    free sulfur dioxide  total sulfur dioxide  density    pH  sulphates  \
# ...

# %%
data.shape
# Out:
# (6497, 13)

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 6497 entries, 0 to 6496
# Data columns (total 13 columns):
#  #   Column                Non-Null Count  Dtype
# ---  ------                --------------  -----
#  0   fixed acidity         6497 non-null   float64
#  1   volatile acidity      6497 non-null   float64
#  2   citric acid           6497 non-null   float64
#  3   residual sugar        6497 non-null   float64
#  4   chlorides             6497 non-null   float64
#  5   free sulfur dioxide   6497 non-null   float64
#  6   total sulfur dioxide  6497 non-null   float64
#  7   density               6497 non-null   float64
#  8   pH                    6497 non-null   float64
#  9   sulphates             6497 non-null   float64
#  10  alcohol               6497 non-null   float64
#  11  quality               6497 non-null   int64
#  12  type                  6497 non-null   object
# dtypes: float64(11), int64(1), object(1)
# memory usage: 660.0+ KB

# %%
data.isna().sum()
# Out:
# fixed acidity           0
# volatile acidity        0
# citric acid             0
# residual sugar          0
# chlorides               0
# free sulfur dioxide     0
# total sulfur dioxide    0
# density                 0
# pH                      0
# sulphates               0
# alcohol                 0
# quality                 0
# type                    0
# dtype: int64

# %%
data.describe()
# Out:
#        fixed acidity  volatile acidity  citric acid  residual sugar  \
# count    6497.000000       6497.000000  6497.000000     6497.000000
# mean        7.215307          0.339666     0.318633        5.443235
# std         1.296434          0.164636     0.145318        4.757804
# min         3.800000          0.080000     0.000000        0.600000
# 25%         6.400000          0.230000     0.250000        1.800000
# 50%         7.000000          0.290000     0.310000        3.000000
# 75%         7.700000          0.400000     0.390000        8.100000
# max        15.900000          1.580000     1.660000       65.800000
#
#          chlorides  free sulfur dioxide  total sulfur dioxide      density  \
# count  6497.000000          6497.000000           6497.000000  6497.000000
# mean      0.056034            30.525319            115.744574     0.994697
# std       0.035034            17.749400             56.521855     0.002999
# ...

# %%
data.columns
# Out:
# Index(['fixed acidity', 'volatile acidity', 'citric acid', 'residual sugar',
#        'chlorides', 'free sulfur dioxide', 'total sulfur dioxide', 'density',
#        'pH', 'sulphates', 'alcohol', 'quality', 'type'],
#       dtype='object')

# %%
import seaborn as sns
import matplotlib.pyplot as plt

# %%
sns.set_theme(style="darkgrid")
sns.histplot(data['quality'],color="yellow",bins=10,kde=True)
plt.title('Distribution of Wine Quality')
plt.xlabel('Quality')
plt.ylabel('Frequency')
plt.show()

# %%
sns.set_theme(style="darkgrid")
sns.histplot(data['alcohol'],color="yellow",bins=10,kde=True)
plt.title('Distribution of alcohol in Wine ')
plt.xlabel('Quality')
plt.ylabel('Frequency')
plt.show()

# %%
sns.set_theme(style="darkgrid")
sns.boxplot(data['alcohol'],color="yellow")
plt.title('Distribution of alcohol in Wine ')
plt.xlabel('Quality')
plt.ylabel('Frequency')
plt.show()

# %%
sns.countplot(data['type'])
plt.title('Distribution of alcohol in Wine ')

plt.show()

# %%
from sklearn.preprocessing import LabelEncoder
le=LabelEncoder()
data["type"]=le.fit_transform(data["type"])

# %%
#train test split
from sklearn.model_selection import train_test_split
x=data.drop("type",axis=1)
y=data["type"]

# %%
x_train,x_test,y_train,y_test=train_test_split(x,y,test_size=0.2,random_state=42)

# %%
#decision tree classifier
from sklearn.tree import DecisionTreeClassifier
dt=DecisionTreeClassifier()
dt.fit(x_train,y_train)
# Out:
# DecisionTreeClassifier()

# %%
y_pred=dt.predict(x_test)

# %%
#here we see conclusion matrix and accuracy
from sklearn.metrics import confusion_matrix,accuracy_score
print("accuracy",accuracy_score(y_test,y_pred))
# Out:
# accuracy 0.9838461538461538

# %%
cm=confusion_matrix(y_test,y_pred)

# %%
sns.heatmap(cm,annot=True,fmt="d",cmap="Reds")
plt.title("Confusion  Matrix")
plt.xlabel("Predicted Labels")
plt.ylabel("True Labels")
plt.show()
#327 is red wine and our model also predicted red wine

# %%
#for random forest
from sklearn.ensemble import RandomForestClassifier
rf=RandomForestClassifier()
rf.fit(x_train,y_train)
y_pred=rf.predict(x_test)

# %%
print("accuracy",accuracy_score(y_test,y_pred))
# Out:
# accuracy 0.9953846153846154

# %%
cm=confusion_matrix(y_test,y_pred)
sns.heatmap(cm,annot=True,fmt="d",cmap="Greens")
plt.title("Confusion  Matrix")
plt.xlabel("Predicted Labels")
plt.ylabel("True Labels")
plt.show()

# %%
#XGboost
from xgboost import XGBClassifier
xgb=XGBClassifier()
xgb.fit(x_train,y_train)
y_pred=xgb.predict(x_test)

# %%
from sklearn.metrics import confusion_matrix,accuracy_score
print("accuracy",accuracy_score(y_test,y_pred))
# Out:
# accuracy 0.9946153846153846

# %%
cm=confusion_matrix(y_test,y_pred)
sns.heatmap(cm,annot=True,fmt="d",cmap="Blues")
plt.title("Confusion  Matrix")
plt.xlabel("Predicted Labels")
plt.ylabel("True Labels")
plt.show()

# %%
importances=xgb.feature_importances_
features=x.columns

# %%
fea_imp=pd.DataFrame({"Feature":features,"Importance":importances})

# %%
fea_imp=fea_imp.sort_values(by="Importance",ascending=False)

# %%
fea_imp.head(5)
# Out:
#                 Feature  Importance
# 4             chlorides    0.428246
# 6  total sulfur dioxide    0.379279
# 1      volatile acidity    0.063866
# 0         fixed acidity    0.026950
# 7               density    0.021887

# %%
plt.figure(figsize=(20,5))
sns.barplot(x="Feature",y="Importance",data=fea_imp, color= "#F5F5DC")
plt.xticks(rotation=90)
plt.show()

# %%
import joblib# for saving the model
joblib.dump(xgb,"wine_type_model.pkl")
# Out:
# ['wine_type_model.pkl']

# %%
from google.colab import files# for downloading
files.download("wine_type_model.pkl")

# %%
uploaded = files.upload()
# Out:
#      <input type="file" id="files-cf246c09-77e6-4a0c-bf3d-1072bbdcbbf1" name="files[]" multiple disabled
#         style="border:none" />
#      <output id="result-cf246c09-77e6-4a0c-bf3d-1072bbdcbbf1">
#       Upload widget is only available when the cell has been executed in the
#       current browser session. Please rerun this cell to enable.
#       </output>
#       <script>// Copyright 2017 Google LLC
# //
# // Licensed under the Apache License, Version 2.0 (the "License");
# // you may not use this file except in compliance with the License.
# // You may obtain a copy of the License at
# //
# //      http://www.apache.org/licenses/LICENSE-2.0
# //
# // Unless required by applicable law or agreed to in writing, software
# // distributed under the License is distributed on an "AS IS" BASIS,
# // WITHOUT WARRANTIES OR CONDITIONS OF ANY KIND, either express or implied.
# // See the License for the specific language governing permissions and
# // limitations under the License.
#
# ...

# %%
model=joblib.load("wine_type_model.pkl")
